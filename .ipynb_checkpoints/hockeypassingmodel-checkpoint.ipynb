# %% [markdown]
# <a href="https://colab.research.google.com/github/yaobviously/DataCup2021/blob/main/hockeypassingmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
import math

import scipy
from scipy.stats import beta
from scipy.stats import binom

from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import permutation_importance
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import make_pipeline
from sklearn.inspection import (partial_dependence, 
                                PartialDependenceDisplay)
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report, roc_curve, roc_auc_score, accuracy_score

from xgboost import XGBClassifier
import shap
import optuna

warnings.filterwarnings("ignore", message="ntree_limit is deprecated*")
plt.style.use('default')

URL = 'https://raw.githubusercontent.com/yaobviously/DataCup2021/main/modifiedohl.csv'

# %%
def wrangle(URL):    
    
    df = pd.read_csv(URL,
                   parse_dates = ['game_date'],
                   index_col = 'game_date')
    
    # changing the features around so i can get team_skater_adv
    df['home_skater_adv'] = df['home_team_skaters'] - df['away_team_skaters']
    df['home_score_diff'] = df['home_team_goals'] - df['away_team_goals']
    
    # adding a feature
    df['team_skater_adv'] = np.where(df['team'] == df['home_team'],
                                 df['home_skater_adv'],
                                 df['home_skater_adv'] * -1)
    # dropping columns i made awhile ago that i don't need to build models, 
    # although they may be handy for communicating insights. all of the score
    # and player differentials can now, i see, be reduced to single columns for
    # the purposes of model building

    col_drop = ['Unnamed: 0', 'possSet', 'shots_next_ten', 'goal_next_ten', 
              '5on5', '5on4home', '5on3home', '5on4away', '5on3away', 
              '4on4', 'tie', 'home_ahead_1', 'home_ahead_2', 'home_ahead_3ormore',
              'away_ahead_1', 'away_ahead_2', 'away_ahead_3ormore', 'home_team',
              'away_team', 'is_shot', 'detail_2']

    df = df.drop(columns = col_drop).copy()
    df = df.rename(columns = {'detail_3' : 'traffic', 'detail_4' : 'one_timer',
                            'detail_1' : 'pass_type'})

    # adding feature
    df['is_shot'] = [1 if event in ['Goal', 'Shot'] else 0 for event in df['event']]

    # converting the clock column to the seconds remaining in the period in the
    # ugliest way imaginable

    df['min'] = df.clock.apply(lambda x: datetime.datetime.strptime(x,'%M:%S')).dt.minute
    df['sec'] = df.clock.apply(lambda x: datetime.datetime.strptime(x, '%M:%S')).dt.second
    df['period_sec_rem'] = df['min'] * 60 + df['sec']

    df.drop(columns = 'clock', inplace = True)

    # calculating the seconds remaining in the game, mostly for practice (needed!)

    def gamesecs(x):

        if x['period'] == 1:
            return x['period_sec_rem'] + 2400

        elif x['period'] == 2:
            return x['period_sec_rem'] + 1200

        else:
            return x['period_sec_rem']

    df['game_sec_rem'] = df.apply(gamesecs, axis = 1)

    # creating new columns that contain info on prior game states

    df['x_coordinate_1back'] = df['x_coordinate'].shift()
    df['y_coordinate_1back'] = df['y_coordinate'].shift()
    df['x_coordinate_2back'] = df['x_coordinate'].shift(2)
    df['y_coordinate_2back'] = df['y_coordinate'].shift(2)
    df['event_1back'] = df['event'].shift()
    df['event_2back'] = df['event'].shift(2)

    df['sec_last_event'] = np.abs(df.groupby(['gameid', 'period'])['period_sec_rem'].diff())
    df['sec_2ndlast_event'] = np.abs(df.groupby(['gameid', 'period'])['period_sec_rem'].diff(2))

    # dropping redundant and leaky columns. note 'event' may be useful for
    # finding and creating useful (and non-leaky) features

    df.drop(columns = ['min', 'sec'], inplace = True)

    # dropping columns with negligible importance. note 'team' & 'period may be 
    # useful for finding and creating useful (and non-leaky) features.

    lowimp_columns = ['away_team_goals', 'home_team_goals', 
                      'home_team_skaters','away_team_skaters', 'traffic', 'event_2back',
                      'game_sec_rem', 'period', 'gameid', 'one_timer',
                      'is_shot',  'is_goal', 'period_sec_rem',
                      'sec_last_event', 'x_coordinate_1back', 'y_coordinate_1back',
                      'event_1back', 'x_coordinate_2back', 'y_coordinate_2back',
                      'sec_2ndlast_event', 'home_score_diff', 'home_skater_adv']

    df.drop(lowimp_columns, axis = 1, inplace = True)

    # Filtering the DataFrame to include only rows in which a pass was recorded

    df = df[df['event'].isin(['Play', 'Incomplete Play'])]
    df['event'] = df['event'].map({'Play' : 1, 'Incomplete Play' : 0})

    # adding a feature or two

    df['forward_pass'] = (df['x_coordinate_2'] > df['x_coordinate']).astype(int)
    df['x_dist'] = df['x_coordinate_2'] - df['x_coordinate']
    df['y_dist'] = df['y_coordinate_2'] - df['y_coordinate']
    df['pass_distance'] = np.sqrt(df['x_dist'] ** 2 + df['y_dist'] ** 2)
    df['pass_angle'] = [math.asin(x) for x in (df['y_dist'] / df['pass_distance'])]

    df.drop(columns = ['x_dist', 'y_dist'], inplace = True)
    
    df = df.rename(columns = {'event' : 'pass_success'})

    return df

# %%
# below i create a smaller dataframe with information that will be stitched back
# onto the main df to assess and compare player skill

df = wrangle(URL)

# manually converting pass type to a binary to eliminate the need
# for category_encoders library (late addition)
df['pass_type'] = df['pass_type'].map({'Direct' : 1, 'Indirect' : 0})

# dropping all nans - they were NaNs in the angle column because 
# the pass x, y and x_2, y_2 were the same (0 distance pass)
df.dropna(inplace=True)

player_eval = df[['player', 'player_2', 'team']].copy()

df.drop(columns = player_eval.columns, inplace = True)

# %%
# i notice going over my previous work that i had 'home_skater_adv'
# i've changed this to 'team_skater_adv' (if the event is pass, team = passer's team)
df.head()
# Out:
#             pass_success  x_coordinate  y_coordinate  pass_type  \
# game_date
# 2019-09-20             0            45            49          1
# 2019-09-20             0            82            49          1
# 2019-09-20             1             6            60          0
# 2019-09-20             1            82            50          0
# 2019-09-20             1             9            74          0
#
#             x_coordinate_2  y_coordinate_2  team_skater_adv  forward_pass  \
# game_date
# 2019-09-20            74.0            35.0                0             1
# 2019-09-20            94.0            46.0                0             1
# 2019-09-20            29.0             2.0                0             1
# 2019-09-20            82.0            54.0                0             0
# 2019-09-20             4.0            29.0                0             0
#
#             pass_distance  pass_angle  ozone_entry_pass
# game_date
# 2019-09-20      32.202484   -0.449760                 0
# 2019-09-20      12.369317   -0.244979                 0
# 2019-09-20      62.393910   -1.193266                 0
# 2019-09-20       4.000000    1.570796                 0
# 2019-09-20      45.276926   -1.460139                 0

# %%
# what does the distribution of passing angles look like
# as a note, the 0 radian passes are where the y-coordinate
# doesn't change - they're directly ahead.
fig, ax = plt.subplots(figsize=(6,4))

sns.histplot(df['pass_angle'])

plt.xlabel("Pass Angle (radians)")
plt.title("The Distribution of Pass Angles")

plt.show()

# %%
# creating an example of a 0 radian pass. in general,
# these are passes along the boards

example = df[df['pass_angle'] == 0].sample(1)

fig, ax = plt.subplots(figsize=(6, 4))

plt.scatter(x=example['x_coordinate'], y=example['y_coordinate'], c='green', label='passer')
plt.scatter(x=example['x_coordinate_2'], y=example['y_coordinate_2'], c='blue', label='recipient')

plt.xlim(0, 200)
plt.ylim(0, 85)
plt.grid()

plt.legend()
plt.show()

# %%
# a kernel density plot of where passes tend to go
sns.kdeplot(x=df.x_coordinate_2, y=df.y_coordinate_2, cmap="Reds")
# Out:
# <Axes: xlabel='x_coordinate_2', ylabel='y_coordinate_2'>

# %%
# this is the baseline frequency of pass success

baseline_frequency = df.pass_success.value_counts(normalize = True).max()
print('Using the base rate as the predictor would yield an accuracy of:', baseline_frequency)
# Out:
# Using the base rate as the predictor would yield an accuracy of: 0.7237914515025198

# %%
# identifying the target and dividing the data into train, eval, and test sets.
# i've modified the dates to give more sensible proportions

target = 'pass_success'

train_threshold = '2020-02-28'
test_threshold = '2020-03-14'

mask = df.index < train_threshold
mask2 = df.index > test_threshold

X = df.drop(target, axis = 1)
y = df[target]

X_train, y_train = X[mask], y[mask]
X_val, y_val = X[~mask & ~mask2], y[~mask & ~mask2]
X_test, y_test = X[~mask], y[~mask]

print("the size of our train, val, and test sets are:",
      X_train.shape[0],
      X_val.shape[0],
      X_test.shape[0])
# Out:
# the size of our train, val, and test sets are: 28142 4004 4004

# %%
def objective(trial):
    "the function to optimize the xgboost hyperparameters"
    
    params = {
        'learning_rate' : trial.suggest_float("learning_rate", 1e-3, 1e-1, log=True),
        'max_depth' : trial.suggest_int('max_depth', 2, 10),
        'n_estimators' : trial.suggest_int('n_estimators', 25, 500, step=5),
        'min_child_weight' : trial.suggest_int('min_child_weight', 1, 25)
    }
    
    model_xgb = XGBClassifier(**params, eval_method = 'auc')
    
    model_xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=15)
    
    test_preds = model_xgb.predict_proba(X_val)[:, 1]
    
    return roc_auc_score(y_val, test_preds)

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=55)

# %%
# specifying models. the hyperparameters for XGB were 
# optimized above. i suspect combining the neural network
# and the tree model may lead to slightly better predictions
# in part because the nn_model will smooth out some of the 
# feature interactions


nn_model = make_pipeline(StandardScaler(), MLPClassifier())


model_xgb = XGBClassifier(objective = 'binary:logistic',
                          eval_method = 'auc',
                          max_depth = 6,
                          min_child_weight=4,
                          n_estimators = 270,
                          learning_rate=0.06945966254666942)


nn_model.fit(X_train, y_train)
model_xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=15);

# %%
# plotting the ROC curve for the XGBoost passing model

reg_fp, reg_tp, reg_thr = roc_curve(y_test, nn_model.predict_proba(X_test)[:,1])
fp, tp, thr = roc_curve(y_test, model_xgb.predict_proba(X_test)[:,1])

plt.plot(reg_fp, reg_tp, c = 'green', label='Neural Network Model')
plt.plot(fp, tp, c = 'blue', label='XGBoost Model')
plt.plot([0,1], ls = '--', c = 'orange')

plt.title('ROC Curve for the XGBoost Model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.gcf().set_size_inches(4,3)
plt.legend()
plt.show();

# %%
print('The AUC score for the Neural Network model is:', roc_auc_score(y_test, nn_model.predict_proba(X_test)[:,1]))
print('The accuracy score for the XGBoost model is:', accuracy_score(y_test, model_xgb.predict_proba(X_test)[:,1].round(0)))
print('The AUC score for the XGBoost model is:', roc_auc_score(y_test, model_xgb.predict_proba(X_test)[:,1]))
# Out:
# The AUC score for the Neural Network model is: 0.7279166565556843
# The accuracy score for the XGBoost model is: 0.7672327672327672
# The AUC score for the XGBoost model is: 0.7572636233248231

# %%
# creating a feature importances series to display
# the feature importances according to the xgboost model

features = X.columns
importances = model_xgb.feature_importances_

pd.Series(importances, index = features).sort_values(ascending=False)
# Out:
# team_skater_adv    0.329968
# forward_pass       0.229158
# pass_type          0.102389
# y_coordinate_2     0.090716
# x_coordinate_2     0.085463
# pass_angle         0.043679
# x_coordinate       0.041010
# y_coordinate       0.040026
# pass_distance      0.037592
# dtype: float32

# %%
# creating a feature importances dataframe using permutation importance 

perm_imp = permutation_importance(model_xgb, X_test, y_test, n_repeats = 12)

perm_dict = {
    'means' : perm_imp['importances_mean'],
    'std' : perm_imp['importances_std']
}

# creating the dataframe to display the permutation importances
pd.DataFrame(perm_dict, index = features).sort_values(by='means', ascending=False)
# Out:
#                     means       std
# y_coordinate_2   0.051906  0.002709
# x_coordinate_2   0.041250  0.002386
# pass_type        0.040480  0.003878
# x_coordinate     0.014590  0.003316
# pass_angle       0.006535  0.001459
# forward_pass     0.004745  0.001638
# team_skater_adv  0.004017  0.002108
# pass_distance    0.001644  0.001898
# y_coordinate     0.001082  0.002223

# %%
# using the sklearn partial dependence plots to display
# how individual and average predictions change as 
# the man advantage and the forwardness of the pass change

variables = ['team_skater_adv', 'forward_pass']

features_info = {
    "features": variables,
    "kind": ['both', 'both'],
    "centered": True,
}

PartialDependenceDisplay.from_estimator(model_xgb, X_test, **features_info)

plt.title("ICE and PDP for Pass Type (direct) and Forward Pass")
plt.tight_layout()
plt.show()

# %%
variables = ['team_skater_adv', 'pass_distance', ('team_skater_adv', 'pass_distance')]

features_info = {
    "features": variables,
    "kind": ['both', 'both', 'average'],
    "centered": True,
}

PartialDependenceDisplay.from_estimator(model_xgb, X_test, **features_info)

plt.show()

# %%
features = ("x_coordinate_2", "y_coordinate_2")

pdp = partial_dependence(
    model_xgb, X_test, features=features, kind="average", grid_resolution=35
)

XX, YY = np.meshgrid(pdp["values"][0], pdp["values"][1])

fig, ax = plt.subplots(figsize=(5.5, 5))

C = pdp["average"].reshape(35, 35)

contour = ax.contourf(XX, YY, C, cmap='Blues')

ax.set_xticks([])
ax.set_yticks([])

cbar = fig.colorbar(contour, ax=ax)
cbar.set_label("Predicted Pass Completion Percentage")

plt.title("Location of Pass Recipient and Model Predictions")
plt.show()

# %%
shap_explainer = shap.TreeExplainer(model_xgb)
shap_values = shap_explainer.shap_values(X_test)

shap.summary_plot(shap_values,
                  X_test,
                  show = False)

plt.title('Shapley Values for Pass Model Features')
plt.gcf().set_size_inches(7,5)
plt.savefig('shapvalspass.png')
plt.show();
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
# stitching the player data back onto the dataframe to enable player comparisons
# using the model's output. 

features = X_test.columns

player_df = pd.concat([df, player_eval], axis =1)
player_df['predicted_pass_prob'] = model_xgb.predict_proba(df[features])[:,1]
otters = player_df[player_df['team'] == 'Erie Otters']

# %%
# creating a dataframe of Erie Otters players when they're the passer

otters_passers = otters.groupby('player').agg(avg_model_pass_prob = ('predicted_pass_prob', 'mean'),
                                              pass_success_rate = ('pass_success', 'mean'),
                                              total_passes = ('player', 'count'))

# %%
# expanding the otters players passing df by calculating their "passes above exp"

otters_passers['expected_successes'] = otters_passers['avg_model_pass_prob'] * otters_passers['total_passes']
otters_passers['actual_successes'] = otters_passers['pass_success_rate'] * otters_passers['total_passes']
otters_passers['successes_above_expectation'] = (otters_passers['actual_successes'] - otters_passers['expected_successes']).round(1)
otters_passers['PAEper100'] = otters_passers['successes_above_expectation'] / (otters_passers['total_passes']/100)

otters_stats = otters_passers[otters_passers['total_passes'] >= 200][['total_passes', 'avg_model_pass_prob', 'successes_above_expectation', 'PAEper100']].sort_values(by='PAEper100', ascending=False)

otters_stats
# Out:
#                     total_passes  avg_model_pass_prob  \
# player
# Luke Beamish                 325             0.744175
# Matthew MacDougall           200             0.701502
# Jamie Drysdale              1386             0.775389
# Chad Yetman                 1112             0.744223
# Kyen Sopa                    326             0.727787
# Maxim Golod                 1415             0.723363
# Jacob Golden                1025             0.755711
# Drew Hunter                  858             0.746654
# Kurtis Henry                1122             0.721345
# Daniel Murphy                220             0.832192
# Brendan Sellan               740             0.698487
# Elias Cohen                  504             0.712335
# Noah Sedore                  290             0.680653
# Brendan Hoffmann             512             0.690007
# Daniel D'Amato               700             0.669241
# Emmett Sproule               797             0.685966
# Jack Duff                   1068             0.723099
# Brendan Kischnick            255             0.706290
# Danial Singer                211             0.711948
# Cameron Morton               568             0.711550
# Connor Lockhart              625             0.710592
# Austen Swankler              944             0.693502
# Hayden Fowler                881             0.684846
#
#                     successes_above_expectation  PAEper100
# player
# Luke Beamish                               16.1   4.953846
# Matthew MacDougall                          6.7   3.350000
# Jamie Drysdale                             46.3   3.340548
# Chad Yetman                                36.4   3.273381
# Kyen Sopa                                   9.7   2.975460
# Maxim Golod                                41.4   2.925795
# Jacob Golden                               26.4   2.575610
# Drew Hunter                                20.4   2.377622
# Kurtis Henry                               20.7   1.844920
# Daniel Murphy                               3.9   1.772727
# Brendan Sellan                              8.1   1.094595
# Elias Cohen                                 4.0   0.793651
# Noah Sedore                                 0.6   0.206897
# Brendan Hoffmann                            0.7   0.136719
# Daniel D'Amato                             -0.5  -0.071429
# Emmett Sproule                             -3.7  -0.464241
# Jack Duff                                  -7.3  -0.683521
# Brendan Kischnick                          -2.1  -0.823529
# Danial Singer                              -2.2  -1.042654
# Cameron Morton                             -8.2  -1.443662
# Connor Lockhart                           -12.1  -1.936000
# Austen Swankler                           -26.7  -2.828390
# Hayden Fowler                             -45.3  -5.141884

# %%
# Plotting pass completions gained per 100 pass attempts. Note that Jamie Drysdale
# and Maxim Golod are considered the two top prospects on the Erie Otters, so
# this result accords with the consensus among scouting professionals. 

otters_passers_filtered = (
    otters_passers[otters_passers['total_passes'] >= 400]
    .reset_index()
    .sort_values(by='PAEper100', ascending=False)
)

plt.figure(figsize=(8, 6))
ax = sns.barplot(
    x='PAEper100',
    y='player',
    data=otters_passers_filtered,
    palette='mako',
    orient='h'
)

ax.set_title('Pass Completions Gained', pad=20, fontsize=12)
ax.set_ylabel('')
ax.set_xlabel('Per 100 Pass Attempts', fontsize=12)
sns.despine()

plt.show()

# %%
# creating a DataFrame of Erie Otter players when they're the pass target

otters_targets = otters.groupby('player_2').agg(avg_model_rec_prob = ('predicted_pass_prob', 'mean'),
                                                 receive_succ_rate = ('pass_success', 'mean'),
                                                 total_targets = ('player_2', 'count')
                                                 )

# %%
# expanding the otters players target df by calculating their 
# "passes received over expectation" and passes_received_over_expectation/100

otters_targets['expected_successes'] = otters_targets['avg_model_rec_prob'] * otters_targets['total_targets']
otters_targets['actual_successes'] = otters_targets['receive_succ_rate'] * otters_targets['total_targets']
otters_targets['passes_rec_above_expectation'] = (otters_targets['actual_successes'] - otters_targets['expected_successes']).round(1)

otters_targets['SAEper100'] = (otters_targets['passes_rec_above_expectation'] / (otters_targets['total_targets'] / 100)).round(2)

otters_targets[otters_targets['total_targets'] >= 200][['total_targets', 'avg_model_rec_prob', 'passes_rec_above_expectation','SAEper100']].sort_values(by='SAEper100', ascending=False)
# Out:
#                     total_targets  avg_model_rec_prob  \
# player_2
# Jamie Drysdale               1018            0.839473
# Jacob Golden                  661            0.828458
# Jack Duff                     630            0.814285
# Austen Swankler              1087            0.705195
# Drew Hunter                   585            0.847799
# Kurtis Henry                  733            0.835582
# Cameron Morton                357            0.822478
# Hayden Fowler                1075            0.695672
# Luke Beamish                  201            0.844348
# Chad Yetman                  1395            0.682892
# Maxim Golod                  1775            0.725153
# Brendan Sellan               1026            0.661143
# Emmett Sproule               1088            0.681754
# Brendan Hoffmann              703            0.642006
# Kyen Sopa                     432            0.681506
# Daniel D'Amato                933            0.674325
# Danial Singer                 371            0.637071
# Elias Cohen                   551            0.640342
# Noah Sedore                   356            0.660832
# Connor Lockhart               795            0.664840
# Matthew MacDougall            293            0.675225
#
#                     passes_rec_above_expectation  SAEper100
# player_2
# Jamie Drysdale                              53.4       5.25
# Jacob Golden                                25.4       3.84
# Jack Duff                                   20.0       3.17
# Austen Swankler                             33.5       3.08
# Drew Hunter                                 15.0       2.56
# Kurtis Henry                                18.5       2.52
# Cameron Morton                               4.4       1.23
# Hayden Fowler                                7.2       0.67
# Luke Beamish                                 1.3       0.65
# Chad Yetman                                  6.4       0.46
# Maxim Golod                                  6.9       0.39
# Brendan Sellan                               2.7       0.26
# Emmett Sproule                               2.3       0.21
# Brendan Hoffmann                            -0.3      -0.04
# Kyen Sopa                                   -2.4      -0.56
# Daniel D'Amato                              -8.1      -0.87
# Danial Singer                               -5.4      -1.46
# Elias Cohen                                -13.8      -2.50
# Noah Sedore                                 -9.3      -2.61
# Connor Lockhart                            -24.5      -3.08
# Matthew MacDougall                         -19.8      -6.76

# %%
# using simple grid approximation to update a prior on the passing skill of
# Aidan campbell of the Erie Otters. good practice!

# specifying the range of possible values for Aidan Campbell's true passing 
# success rate

possible_rates = [n for n in np.linspace(0.55, 0.95, 100)]

# computing prior probabilities for pass success probability using the beta distribution.
# the prior comes from the model's estimate of pass success given the passes 
# plus my domain expertise with respect to the uncertainty. subjective. note
# that he attempted very low-risk passes. 

prior_over_rates = beta.pdf(possible_rates, a = 8, b = 5)
prior_normed = prior_over_rates/prior_over_rates.sum()

# computing the likelihood of the observations -- 177 successful passes out of 
# 202 total passes (see otters_passers dataframe, Aidan Campbell)

successes = otters_passers.loc['Aidan Campbell']['actual_successes']
attempts = otters_passers.loc['Aidan Campbell']['total_passes']

likelihoods = binom.pmf(successes, attempts, possible_rates)
likelihoods_normed = likelihoods/likelihoods.sum()

# computing the posterior by multiplying the likelihoods by the prior

posterior_unnormed = likelihoods * prior_over_rates
posterior_normed = posterior_unnormed/posterior_unnormed.sum()

# plotting the prior and the posterior. the plot shows that we are much more
# confident that Aidan Campbell has average passing skill after adjusting for the
# difficulty of his passes. note that he chooses very safe passes, which itself
# indicates something interesting about his skillset/potential, but that's another
# topic. 


plt.plot(possible_rates, prior_normed, lw=2, label = 'prior')
plt.plot(possible_rates, posterior_normed, lw = 2, c = 'orange', label = 'posterior')
plt.title("What We Learned")
plt.xlabel('True Pass Success Rate')
plt.ylabel('')
plt.legend(loc = 'best')
plt.gcf().set_size_inches(4,3)
sns.despine()
plt.show();
